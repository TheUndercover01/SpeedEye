# %%
from deep_sort.deep_sort.detection import Detection
from deep_sort.deep_sort import nn_matching
from deep_sort.deep_sort.tracker import Tracker as Deeptrack
from deep_sort.tools import generate_detections as gdet

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.13.0'

# %%
class Tracker:
    tracker = None
    encoder = None
    tracks = None

    def __init__(self):
        max_cosine_distance = 0.4
        nn_budget = None

        encoder_model_filename = 'resources/networks/mars-small128.pb'

        metric = nn_matching.NearestNeighborDistanceMetric("cosine", max_cosine_distance, nn_budget)
        self.tracker = Deeptrack(metric)
        self.encoder = gdet.create_box_encoder(encoder_model_filename, batch_size=1)

       

    def update(self, frame, detections):

        if len(detections) == 0:
            self.tracker.predict()
            self.tracker.update([])  
   
            self.update_tracks()
            return

 
        bboxes = np.asarray([d[:-1] for d in detections])
        
        bboxes[:, 2:] = bboxes[:, 2:] - bboxes[:, 0:2]
  
        scores = [d[-1] for d in detections]

     
        features = self.encoder(frame, bboxes)

        dets = []
        for bbox_id, bbox in enumerate(bboxes):
            dets.append(Detection(bbox, scores[bbox_id], features[bbox_id]))

        self.tracker.predict()
        self.tracker.update(dets)
        self.update_tracks()

    def update_tracks(self):
        tracks = []
        for track in self.tracker.tracks:
            if not track.is_confirmed() or track.time_since_update > 1:
                continue
            bbox = track.to_tlbr()

            id = track.track_id
    
            
            tracks.append(Track(id, bbox))

        self.tracks = tracks


class Track:
    track_id = None
    bbox = None

    def __init__(self, id, bbox):
        self.track_id = id
        self.bbox = bbox

# %%
import math
def estimate_speed(time1,time2 ):
    #Euclidean Distance Formula
    
    dist = 300
    speed = dist/(time2 - time1)
    return speed*3.6

# %%
from ultralytics import YOLO
import matplotlib
import matplotlib.pyplot as plt
import easyocr
def liscence_plate(name_of_img , bbox , track_id):
    x1, y1, x2, y2 = bbox
    previous_directory = os.getcwd()
    os.chdir('./number_plate_detection_img/frame')
   

    img =  plt.imread(name_of_img )
    os.chdir(previous_directory)
    plt.imshow(img)
  
    
    crop_to_car = img[int(y1):int(y2) , int(x1):int(x2)  ]
    
    os.chdir('./number_plate_detection_img/bbox')
    plt.imsave(f'imgcar{track_id}.png' , crop_to_car)
    img = cv2.imread(f'imgcar{track_id}.png')
    plt.imshow(crop_to_car)
    os.chdir(previous_directory)
    license_plate_detector = YOLO('./license_plate/license_plate_detector.pt')
    
   
    detect = license_plate_detector(img)

    
    for detections_ in detect :
        detection = []
        if detections_!=[]:
            
            for det in detections_.boxes.data.tolist():
                xmin  = int(det[0])
                ymin = int(det[1])
                xmax = int(det[2])
                ymax = int(det[3])
                confidence = det[4]
               
                detection.append([xmin , ymin , xmax , ymax , confidence ])

    
        
    if detection!=[]:
        crop = img[ymin : ymax , xmin:xmax , :]
        license_plate_crop_gray = cv2.cvtColor(crop, cv2.COLOR_BGR2GRAY)
        _, license_plate_crop_thresh = cv2.threshold(license_plate_crop_gray, 64, 255, cv2.THRESH_BINARY_INV)
        os.chdir('./license_plate')
        plt.imsave(f'lisc{track_id}.png' , license_plate_crop_thresh)
        
     
        os.chdir(previous_directory)
        
        reader = easyocr.Reader(['en'])
        result = reader.readtext(license_plate_crop_thresh)
        print(result)
        if result!=[] :
            if result[0][-1]>0.5 :
                
                return result[0][-2]
            else:
                return "Not Accurate yet"
        else:
            return None
    else:
        return None

# %%
import numpy as np
import torch
import os
import cv2
import pandas
from ultralytics import YOLO
import random
import time
import matplotlib
import matplotlib.pyplot as plt
model = YOLO('yolov8m.pt')
cap = cv2.VideoCapture(os.path.join( 'hey.mp4'))

tracker = Tracker()

threshold  = 0.5
# colors = [(random.randint(0, 255), random.randint(0, 255), random.randint(0, 255)) for j in range(10)]
ret , frame = cap.read()

video_out_path = os.path.join('.', 'ijuii.mp4')

cap_out = cv2.VideoWriter(video_out_path, cv2.VideoWriter_fourcc(*'mp4v'), cap.get(cv2.CAP_PROP_FPS),
                          (frame.shape[1], frame.shape[0]))

vehicle_entering_the_area = {}

vehicle_enter_list = []

time_enter = {}

time_exit = {}

total_frames = {}

speed = {}

speed_exceed = {}

number_plate = {}

not_acc = {}

count = 0
while ret:
   
    
    # Make detections 
    results = model(frame)

    area = [(1383,834) , (1206,1020) , (3183,1020) ,(2928,834) ]
    area2 = [(762,1698) , (492,2157) , (3834,2157) , (3834,1698)]
    for result in results : 
        detections = []
        for det in result.boxes.data.tolist() :
            xmin  = int(det[0])
            ymin = int(det[1])
            xmax = int(det[2])
            ymax = int(det[3])
            confidence = det[4]
         
            if confidence > threshold :
                detections.append([xmin , ymin , xmax , ymax , confidence ])
        
        tracker.update(frame , detections)
        
        for tracks in tracker.tracks: 
            bbox = tracks.bbox
            x1, y1, x2, y2 = bbox
            track_id = tracks.track_id
            cx = int((x1+x2)/2)
            cy = int((y1+y2)/2)
            if cv2.pointPolygonTest(np.array(area , np.int32), (cx,cy) , False) > 0 :
                
                time_enter[track_id] = time.time()
                vehicle_entering_the_area[track_id] = (cx,cy)
                
            if cv2.pointPolygonTest(np.array(area2 , np.int32), (cx,cy) , False) > 0 and track_id in vehicle_entering_the_area : #for the time changing this code to check speed in uper region
                time_exit[track_id] = time.time()
                frame = cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), [0,0,0], 5)
                cv2.putText(frame, f'id : {track_id}', (int(x1), int(y1-10)), cv2.FONT_HERSHEY_SIMPLEX, 1, (36,255,12), 2)
                cv2.circle(frame , (cx,cy) , 5 , [255,255,0] , -1)
                if track_id not in speed :
                    speed_vehicle = estimate_speed(time_enter[track_id] ,time_exit[track_id])
                    speed[track_id] = speed_vehicle
                cv2.putText(frame, f'speed : {speed[track_id]}', (int(x1), int(y1+10)), cv2.FONT_HERSHEY_SIMPLEX, 1, (36,255,12), 2)
                if speed[track_id] > 8 :
                    
                    speed_exceed[track_id] = speed
                    previous_directory = os.getcwd()
                    os.chdir('./number_plate_detection_img/frame')
                    plt.imsave(f'img{track_id}.png' , frame)
                    os.chdir(previous_directory)
                    text = liscence_plate(f'img{track_id}.png' , bbox , track_id)
                   
                    not_acc[track_id] = text
                    if text != 'Not Accurate yet' or None : 
                        
                        number_plate[track_id] = text
                else :
                    cv2.putText(frame, 'Speed Ok!!', (int(x1), int(y1+40)), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255,0), 2)
                
                    
                    
                    
                    
            elif track_id in vehicle_entering_the_area :
                
                frame = cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), [0,0,0], 5)
                cv2.putText(frame, f'id : {track_id}', (int(x1), int(y1-10)), cv2.FONT_HERSHEY_SIMPLEX, 1, (36,255,12), 2)
                cv2.circle(frame , (cx,cy) , 5 , [255,255,0] , -1)
    

            if track_id in not_acc  :
                if track_id in number_plate :
                
                    cv2.putText(frame, f'number_plate : {number_plate[track_id]}', (int(x1), int(y1+40)), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255), 2)
                else:

                    cv2.putText(frame, 'Not Accurate yet', (int(x1), int(y1+40)), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255), 2)

           
                
                
    cv2.polylines(frame , [np.array(area , np.int32)] ,True , (15,220,10) , 6 )
    cv2.polylines(frame , [np.array(area2 , np.int32)] ,True , (15,220,10) , 6 )
    cap_out.write(frame)
    #cv2.imshow('yolo' , frame)
    ret, frame = cap.read()
    count =0
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# 0: 384x640 1 person, 22 cars, 1 bus, 5 trucks, 124.5ms
# Speed: 7.2ms preprocess, 124.5ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 22 cars, 1 bus, 5 trucks, 112.6ms
# Speed: 1.7ms preprocess, 112.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 5 trucks, 106.1ms
# Speed: 2.1ms preprocess, 106.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 21 cars, 1 bus, 4 trucks, 109.4ms
# Speed: 1.5ms preprocess, 109.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 20 cars, 1 bus, 5 trucks, 124.6ms
# Speed: 2.0ms preprocess, 124.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 5 trucks, 112.0ms
# Speed: 1.5ms preprocess, 112.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 4 trucks, 110.1ms
# Speed: 1.7ms preprocess, 110.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 21 cars, 1 bus, 4 trucks, 108.2ms
# Speed: 1.8ms preprocess, 108.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 21 cars, 1 bus, 5 trucks, 107.7ms
# Speed: 1.7ms preprocess, 107.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 22 cars, 1 bus, 4 trucks, 112.5ms
# Speed: 1.6ms preprocess, 112.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 22 cars, 1 bus, 5 trucks, 110.6ms
# Speed: 1.7ms preprocess, 110.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 4 trucks, 112.9ms
# Speed: 1.6ms preprocess, 112.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 5 trucks, 113.7ms
# Speed: 1.6ms preprocess, 113.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 5 trucks, 112.6ms
# Speed: 1.7ms preprocess, 112.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cars, 1 bus, 5 trucks, 112.4ms
# Speed: 4.0ms preprocess, 112.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 5 trucks, 110.1ms
# Speed: 1.6ms preprocess, 110.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cars, 1 bus, 5 trucks, 113.4ms
# Speed: 1.7ms preprocess, 113.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 1 bus, 5 trucks, 107.8ms
# Speed: 1.5ms preprocess, 107.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 21 cars, 1 bus, 5 trucks, 109.5ms
# Speed: 1.7ms preprocess, 109.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 21 cars, 1 bus, 5 trucks, 106.1ms
# Speed: 1.4ms preprocess, 106.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 5 trucks, 107.9ms
# Speed: 1.7ms preprocess, 107.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 22 cars, 1 bus, 5 trucks, 110.1ms
# Speed: 1.5ms preprocess, 110.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 21 cars, 1 bus, 5 trucks, 117.3ms
# Speed: 1.6ms preprocess, 117.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 6 trucks, 115.1ms
# Speed: 1.8ms preprocess, 115.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 7 trucks, 150.1ms
# Speed: 2.2ms preprocess, 150.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 7 trucks, 114.2ms
# Speed: 1.7ms preprocess, 114.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 5 trucks, 114.3ms
# Speed: 2.1ms preprocess, 114.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 cars, 1 bus, 5 trucks, 117.4ms
# Speed: 1.6ms preprocess, 117.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 21 cars, 1 bus, 5 trucks, 112.8ms
# Speed: 1.7ms preprocess, 112.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 6 trucks, 113.9ms
# Speed: 1.9ms preprocess, 113.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 1 bus, 5 trucks, 119.3ms
# Speed: 1.6ms preprocess, 119.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 5 trucks, 119.0ms
# Speed: 1.7ms preprocess, 119.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 21 cars, 1 bus, 5 trucks, 110.5ms
# Speed: 1.6ms preprocess, 110.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 22 cars, 1 bus, 5 trucks, 126.3ms
# Speed: 1.7ms preprocess, 126.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 22 cars, 1 bus, 4 trucks, 124.4ms
# Speed: 1.6ms preprocess, 124.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 22 cars, 1 bus, 3 trucks, 116.8ms
# Speed: 1.9ms preprocess, 116.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 21 cars, 1 bus, 3 trucks, 113.8ms
# Speed: 1.6ms preprocess, 113.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 22 cars, 1 bus, 3 trucks, 123.3ms
# Speed: 1.5ms preprocess, 123.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 20 cars, 1 bus, 3 trucks, 127.2ms
# Speed: 1.8ms preprocess, 127.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 4 trucks, 118.3ms
# Speed: 1.5ms preprocess, 118.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 4 trucks, 131.3ms
# Speed: 1.9ms preprocess, 131.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 24 cars, 1 bus, 4 trucks, 120.9ms
# Speed: 1.5ms preprocess, 120.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 20 cars, 1 bus, 3 trucks, 1 traffic light, 119.1ms
# Speed: 1.7ms preprocess, 119.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 20 cars, 1 bus, 3 trucks, 1 traffic light, 128.7ms
# Speed: 1.8ms preprocess, 128.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 21 cars, 1 bus, 3 trucks, 126.7ms
# Speed: 1.9ms preprocess, 126.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 3 trucks, 125.6ms
# Speed: 1.6ms preprocess, 125.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 21 cars, 1 bus, 4 trucks, 117.5ms
# Speed: 1.6ms preprocess, 117.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 21 cars, 1 bus, 3 trucks, 1 traffic light, 123.7ms
# Speed: 1.6ms preprocess, 123.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 21 cars, 1 bus, 3 trucks, 114.5ms
# Speed: 1.6ms preprocess, 114.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 21 cars, 1 bus, 3 trucks, 120.1ms
# Speed: 1.7ms preprocess, 120.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 3 trucks, 126.2ms
# Speed: 1.9ms preprocess, 126.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cars, 1 bus, 3 trucks, 1 traffic light, 116.0ms
# Speed: 1.8ms preprocess, 116.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 3 trucks, 1 traffic light, 117.7ms
# Speed: 1.6ms preprocess, 117.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cars, 1 bus, 3 trucks, 128.9ms
# Speed: 1.8ms preprocess, 128.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 21 cars, 1 bus, 3 trucks, 119.0ms
# Speed: 1.7ms preprocess, 119.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 3 trucks, 127.8ms
# Speed: 1.6ms preprocess, 127.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 3 trucks, 113.5ms
# Speed: 1.6ms preprocess, 113.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 21 cars, 1 bus, 5 trucks, 117.6ms
# Speed: 1.8ms preprocess, 117.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 21 cars, 1 bus, 4 trucks, 129.0ms
# Speed: 1.8ms preprocess, 129.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 20 cars, 1 bus, 4 trucks, 116.6ms
# Speed: 1.7ms preprocess, 116.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 21 cars, 1 bus, 4 trucks, 122.3ms
# Speed: 1.6ms preprocess, 122.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 21 cars, 1 bus, 4 trucks, 113.6ms
# Speed: 1.5ms preprocess, 113.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 4 trucks, 121.2ms
# Speed: 1.8ms preprocess, 121.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 3 trucks, 113.2ms
# Speed: 1.6ms preprocess, 113.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 3 trucks, 121.0ms
# Speed: 1.9ms preprocess, 121.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 3 trucks, 119.2ms
# Speed: 1.6ms preprocess, 119.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 3 trucks, 125.0ms
# Speed: 1.6ms preprocess, 125.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 21 cars, 1 bus, 3 trucks, 113.9ms
# Speed: 1.6ms preprocess, 113.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 21 cars, 1 bus, 3 trucks, 123.1ms
# Speed: 1.7ms preprocess, 123.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 21 cars, 1 bus, 3 trucks, 119.3ms
# Speed: 1.6ms preprocess, 119.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 21 cars, 1 bus, 4 trucks, 115.8ms
# Speed: 1.7ms preprocess, 115.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 21 cars, 1 bus, 4 trucks, 115.8ms
# Speed: 1.7ms preprocess, 115.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 22 cars, 1 bus, 5 trucks, 117.8ms
# Speed: 1.8ms preprocess, 117.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 5 trucks, 120.2ms
# Speed: 1.7ms preprocess, 120.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 5 trucks, 115.1ms
# Speed: 1.8ms preprocess, 115.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 2 trucks, 118.2ms
# Speed: 1.6ms preprocess, 118.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 4 trucks, 121.4ms
# Speed: 1.8ms preprocess, 121.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 4 trucks, 116.7ms
# Speed: 1.6ms preprocess, 116.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 4 trucks, 124.5ms
# Speed: 1.7ms preprocess, 124.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 4 trucks, 128.2ms
# Speed: 1.8ms preprocess, 128.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 6 trucks, 122.5ms
# Speed: 1.6ms preprocess, 122.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 6 trucks, 118.4ms
# Speed: 1.7ms preprocess, 118.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 4 trucks, 128.9ms
# Speed: 1.8ms preprocess, 128.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 5 trucks, 119.8ms
# Speed: 1.6ms preprocess, 119.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 2 trucks, 116.5ms
# Speed: 1.8ms preprocess, 116.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 2 trucks, 125.6ms
# Speed: 1.8ms preprocess, 125.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cars, 1 bus, 3 trucks, 118.7ms
# Speed: 1.9ms preprocess, 118.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 2 trucks, 121.2ms
# Speed: 1.6ms preprocess, 121.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 4 trucks, 116.6ms
# Speed: 2.0ms preprocess, 116.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 4 trucks, 122.7ms
# Speed: 1.6ms preprocess, 122.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cars, 1 bus, 4 trucks, 127.2ms
# Speed: 1.9ms preprocess, 127.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cars, 1 bus, 4 trucks, 120.1ms
# Speed: 1.7ms preprocess, 120.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 3 trucks, 129.2ms
# Speed: 1.9ms preprocess, 129.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 3 trucks, 125.4ms
# Speed: 2.0ms preprocess, 125.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 22 cars, 1 bus, 4 trucks, 117.3ms
# Speed: 1.6ms preprocess, 117.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 4 trucks, 115.7ms
# Speed: 1.7ms preprocess, 115.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 4 trucks, 122.2ms
# Speed: 1.6ms preprocess, 122.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 4 trucks, 129.1ms
# Speed: 1.7ms preprocess, 129.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 4 trucks, 117.6ms
# Speed: 1.7ms preprocess, 117.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 5 trucks, 124.2ms
# Speed: 2.0ms preprocess, 124.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 22 cars, 1 bus, 6 trucks, 125.8ms
# Speed: 1.8ms preprocess, 125.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 1 bus, 4 trucks, 117.6ms
# Speed: 1.9ms preprocess, 117.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 5 trucks, 120.9ms
# Speed: 1.6ms preprocess, 120.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 22 cars, 1 bus, 5 trucks, 114.2ms
# Speed: 1.7ms preprocess, 114.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 22 cars, 1 bus, 6 trucks, 122.9ms
# Speed: 1.6ms preprocess, 122.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 22 cars, 1 bus, 5 trucks, 108.2ms
# Speed: 1.7ms preprocess, 108.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 22 cars, 1 bus, 5 trucks, 121.3ms
# Speed: 1.7ms preprocess, 121.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 23 cars, 1 bus, 5 trucks, 119.3ms
# Speed: 1.7ms preprocess, 119.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 1 bus, 5 trucks, 121.0ms
# Speed: 1.5ms preprocess, 121.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 1 bus, 5 trucks, 121.9ms
# Speed: 1.9ms preprocess, 121.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 5 trucks, 124.5ms
# Speed: 1.5ms preprocess, 124.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 7 trucks, 123.1ms
# Speed: 1.6ms preprocess, 123.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 7 trucks, 125.2ms
# Speed: 1.8ms preprocess, 125.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 5 trucks, 120.1ms
# Speed: 1.7ms preprocess, 120.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 5 trucks, 120.0ms
# Speed: 2.0ms preprocess, 120.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 5 trucks, 114.4ms
# Speed: 1.7ms preprocess, 114.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 6 trucks, 118.3ms
# Speed: 1.7ms preprocess, 118.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 7 trucks, 120.8ms
# Speed: 1.7ms preprocess, 120.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 5 trucks, 114.5ms
# Speed: 1.8ms preprocess, 114.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 6 trucks, 115.8ms
# Speed: 1.6ms preprocess, 115.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 1 bus, 6 trucks, 128.1ms
# Speed: 1.7ms preprocess, 128.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 1 bus, 6 trucks, 126.7ms
# Speed: 1.8ms preprocess, 126.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 7 trucks, 116.2ms
# Speed: 1.8ms preprocess, 116.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cars, 1 bus, 7 trucks, 121.9ms
# Speed: 1.6ms preprocess, 121.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 1 bus, 6 trucks, 125.9ms
# Speed: 1.7ms preprocess, 125.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 5 trucks, 128.9ms
# Speed: 1.7ms preprocess, 128.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 7 trucks, 115.1ms
# Speed: 1.7ms preprocess, 115.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 7 trucks, 115.7ms
# Speed: 1.7ms preprocess, 115.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cars, 1 bus, 5 trucks, 122.6ms
# Speed: 1.6ms preprocess, 122.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 5 trucks, 112.4ms
# Speed: 1.8ms preprocess, 112.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 3 trucks, 116.7ms
# Speed: 1.5ms preprocess, 116.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 4 trucks, 123.3ms
# Speed: 1.7ms preprocess, 123.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 5 trucks, 124.2ms
# Speed: 2.0ms preprocess, 124.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 6 trucks, 126.7ms
# Speed: 1.6ms preprocess, 126.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 3 trucks, 119.8ms
# Speed: 1.7ms preprocess, 119.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 1 bus, 5 trucks, 126.1ms
# Speed: 1.9ms preprocess, 126.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cars, 1 bus, 3 trucks, 131.0ms
# Speed: 1.7ms preprocess, 131.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 23 cars, 1 bus, 3 trucks, 119.2ms
# Speed: 1.6ms preprocess, 119.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 23 cars, 1 bus, 4 trucks, 124.0ms
# Speed: 2.1ms preprocess, 124.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 23 cars, 1 bus, 4 trucks, 115.2ms
# Speed: 1.7ms preprocess, 115.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 23 cars, 1 bus, 5 trucks, 120.6ms
# Speed: 1.8ms preprocess, 120.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 5 trucks, 128.3ms
# Speed: 1.7ms preprocess, 128.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 22 cars, 1 bus, 5 trucks, 119.2ms
# Speed: 1.5ms preprocess, 119.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 21 cars, 1 bus, 4 trucks, 119.3ms
# Speed: 1.7ms preprocess, 119.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 21 cars, 1 bus, 4 trucks, 120.3ms
# Speed: 1.7ms preprocess, 120.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 21 cars, 1 bus, 3 trucks, 123.6ms
# Speed: 1.8ms preprocess, 123.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 20 cars, 1 bus, 4 trucks, 123.2ms
# Speed: 1.6ms preprocess, 123.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 3 trucks, 115.9ms
# Speed: 1.6ms preprocess, 115.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cars, 1 bus, 4 trucks, 114.9ms
# Speed: 1.8ms preprocess, 114.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 4 trucks, 113.9ms
# Speed: 1.7ms preprocess, 113.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 21 cars, 1 bus, 4 trucks, 113.1ms
# Speed: 1.7ms preprocess, 113.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 4 trucks, 125.4ms
# Speed: 1.6ms preprocess, 125.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 23 cars, 1 bus, 4 trucks, 119.2ms
# Speed: 1.6ms preprocess, 119.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 1 bus, 4 trucks, 116.0ms
# Speed: 1.7ms preprocess, 116.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 3 trucks, 119.4ms
# Speed: 1.8ms preprocess, 119.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 4 trucks, 112.4ms
# Speed: 1.7ms preprocess, 112.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 22 cars, 1 bus, 4 trucks, 116.1ms
# Speed: 1.7ms preprocess, 116.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 22 cars, 1 bus, 3 trucks, 117.5ms
# Speed: 1.6ms preprocess, 117.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 23 cars, 1 bus, 4 trucks, 119.4ms
# Speed: 1.6ms preprocess, 119.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 22 cars, 1 bus, 5 trucks, 125.6ms
# Speed: 1.8ms preprocess, 125.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 23 cars, 1 bus, 4 trucks, 125.1ms
# Speed: 1.7ms preprocess, 125.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 21 cars, 1 bus, 4 trucks, 128.8ms
# Speed: 1.5ms preprocess, 128.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 3 trucks, 117.2ms
# Speed: 1.8ms preprocess, 117.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 3 trucks, 118.8ms
# Speed: 2.0ms preprocess, 118.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 3 trucks, 123.2ms
# Speed: 1.6ms preprocess, 123.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 4 trucks, 116.7ms
# Speed: 1.5ms preprocess, 116.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 3 trucks, 128.8ms
# Speed: 1.8ms preprocess, 128.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cars, 1 bus, 3 trucks, 125.6ms
# Speed: 1.7ms preprocess, 125.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cars, 1 bus, 3 trucks, 118.8ms
# Speed: 1.7ms preprocess, 118.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cars, 1 bus, 3 trucks, 127.9ms
# Speed: 1.6ms preprocess, 127.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 cars, 1 bus, 3 trucks, 127.5ms
# Speed: 1.6ms preprocess, 127.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 cars, 1 bus, 3 trucks, 114.2ms
# Speed: 1.5ms preprocess, 114.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 cars, 1 bus, 3 trucks, 120.3ms
# Speed: 1.6ms preprocess, 120.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cars, 1 bus, 3 trucks, 117.5ms
# Speed: 1.8ms preprocess, 117.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cars, 1 bus, 4 trucks, 112.6ms
# Speed: 1.6ms preprocess, 112.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cars, 1 bus, 4 trucks, 128.9ms
# Speed: 1.7ms preprocess, 128.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cars, 1 bus, 3 trucks, 115.9ms
# Speed: 1.7ms preprocess, 115.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 cars, 1 bus, 3 trucks, 122.2ms
# Speed: 1.6ms preprocess, 122.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cars, 1 bus, 3 trucks, 114.2ms
# Speed: 1.6ms preprocess, 114.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 3 trucks, 132.9ms
# Speed: 1.8ms preprocess, 132.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 cars, 1 bus, 3 trucks, 116.2ms
# Speed: 1.7ms preprocess, 116.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 cars, 1 bus, 3 trucks, 120.5ms
# Speed: 1.7ms preprocess, 120.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 cars, 1 bus, 3 trucks, 129.4ms
# Speed: 1.6ms preprocess, 129.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cars, 1 bus, 3 trucks, 116.7ms
# Speed: 1.5ms preprocess, 116.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 cars, 1 bus, 3 trucks, 124.2ms
# Speed: 1.6ms preprocess, 124.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cars, 1 bus, 3 trucks, 120.0ms
# Speed: 1.7ms preprocess, 120.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 3 trucks, 123.3ms
# Speed: 1.7ms preprocess, 123.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 3 trucks, 119.2ms
# Speed: 1.7ms preprocess, 119.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 4 trucks, 115.6ms
# Speed: 1.7ms preprocess, 115.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 1 bus, 4 trucks, 114.7ms
# Speed: 1.8ms preprocess, 114.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 1 bus, 4 trucks, 125.5ms
# Speed: 1.6ms preprocess, 125.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 1 bus, 4 trucks, 117.2ms
# Speed: 1.7ms preprocess, 117.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cars, 1 bus, 3 trucks, 115.9ms
# Speed: 1.8ms preprocess, 115.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cars, 1 bus, 3 trucks, 117.2ms
# Speed: 1.7ms preprocess, 117.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 1 bus, 3 trucks, 119.0ms
# Speed: 1.7ms preprocess, 119.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 1 bus, 4 trucks, 116.9ms
# Speed: 1.8ms preprocess, 116.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 1 bus, 4 trucks, 124.9ms
# Speed: 1.7ms preprocess, 124.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cars, 1 bus, 3 trucks, 118.1ms
# Speed: 1.7ms preprocess, 118.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 2 buss, 3 trucks, 118.9ms
# Speed: 1.8ms preprocess, 118.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 2 buss, 3 trucks, 119.7ms
# Speed: 1.7ms preprocess, 119.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 1 bus, 3 trucks, 116.0ms
# Speed: 1.7ms preprocess, 116.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 1 bus, 2 trucks, 118.6ms
# Speed: 1.7ms preprocess, 118.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cars, 1 bus, 2 trucks, 116.4ms
# Speed: 1.8ms preprocess, 116.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cars, 2 buss, 2 trucks, 122.1ms
# Speed: 1.6ms preprocess, 122.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 1 bus, 2 trucks, 116.1ms
# Speed: 1.6ms preprocess, 116.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 1 bus, 2 trucks, 122.5ms
# Speed: 1.8ms preprocess, 122.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 3 trucks, 121.2ms
# Speed: 1.7ms preprocess, 121.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 1 bus, 2 trucks, 115.5ms
# Speed: 1.6ms preprocess, 115.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 1 bus, 3 trucks, 120.3ms
# Speed: 1.5ms preprocess, 120.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 1 bus, 2 trucks, 119.2ms
# Speed: 1.8ms preprocess, 119.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 1 bus, 2 trucks, 117.7ms
# Speed: 1.5ms preprocess, 117.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 1 bus, 2 trucks, 112.5ms
# Speed: 1.6ms preprocess, 112.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 3 trucks, 111.4ms
# Speed: 1.4ms preprocess, 111.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 4 trucks, 114.5ms
# Speed: 1.4ms preprocess, 114.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 1 bus, 2 trucks, 111.7ms
# Speed: 1.3ms preprocess, 111.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 3 trucks, 108.9ms
# Speed: 1.5ms preprocess, 108.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 1 bus, 4 trucks, 109.2ms
# Speed: 1.2ms preprocess, 109.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 1 bus, 4 trucks, 111.1ms
# Speed: 1.2ms preprocess, 111.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 3 trucks, 109.1ms
# Speed: 1.4ms preprocess, 109.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 2 trucks, 108.5ms
# Speed: 1.4ms preprocess, 108.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 2 trucks, 114.1ms
# Speed: 1.6ms preprocess, 114.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 1 bus, 2 trucks, 116.1ms
# Speed: 1.5ms preprocess, 116.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 1 bus, 2 trucks, 115.4ms
# Speed: 1.6ms preprocess, 115.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 1 bus, 2 trucks, 111.2ms
# Speed: 1.5ms preprocess, 111.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 2 trucks, 113.9ms
# Speed: 1.3ms preprocess, 113.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 2 trucks, 113.9ms
# Speed: 1.4ms preprocess, 113.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 2 trucks, 109.2ms
# Speed: 1.6ms preprocess, 109.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 3 trucks, 113.9ms
# Speed: 1.4ms preprocess, 113.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cars, 1 bus, 3 trucks, 114.6ms
# Speed: 1.4ms preprocess, 114.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 2 trucks, 108.8ms
# Speed: 1.5ms preprocess, 108.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cars, 1 bus, 4 trucks, 106.5ms
# Speed: 1.5ms preprocess, 106.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 3 trucks, 113.1ms
# Speed: 1.5ms preprocess, 113.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 4 trucks, 110.2ms
# Speed: 1.3ms preprocess, 110.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 3 trucks, 111.5ms
# Speed: 1.6ms preprocess, 111.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 3 trucks, 113.1ms
# Speed: 1.4ms preprocess, 113.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 3 trucks, 115.5ms
# Speed: 1.4ms preprocess, 115.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 3 trucks, 108.4ms
# Speed: 1.5ms preprocess, 108.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 3 trucks, 113.5ms
# Speed: 1.5ms preprocess, 113.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 3 trucks, 117.5ms
# Speed: 1.4ms preprocess, 117.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cars, 4 trucks, 112.0ms
# Speed: 1.5ms preprocess, 112.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 4 trucks, 112.6ms
# Speed: 1.4ms preprocess, 112.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cars, 5 trucks, 112.0ms
# Speed: 1.4ms preprocess, 112.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1 bus, 3 trucks, 110.2ms
# Speed: 1.4ms preprocess, 110.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cars, 1 bus, 2 trucks, 109.1ms
# Speed: 1.4ms preprocess, 109.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 1 bus, 3 trucks, 113.1ms
# Speed: 1.5ms preprocess, 113.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 2 buss, 2 trucks, 114.8ms
# Speed: 1.4ms preprocess, 114.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 2 trucks, 112.0ms
# Speed: 1.5ms preprocess, 112.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 1 bus, 2 trucks, 111.6ms
# Speed: 1.4ms preprocess, 111.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cars, 3 trucks, 112.1ms
# Speed: 1.4ms preprocess, 112.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cars, 2 trucks, 109.6ms
# Speed: 1.5ms preprocess, 109.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cars, 1 bus, 2 trucks, 115.0ms
# Speed: 1.3ms preprocess, 115.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 cars, 1 bus, 3 trucks, 111.9ms
# Speed: 1.4ms preprocess, 111.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 24 cars, 1 bus, 3 trucks, 111.2ms
# Speed: 1.4ms preprocess, 111.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cars, 1 bus, 3 trucks, 110.2ms
# Speed: 1.4ms preprocess, 110.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cars, 3 trucks, 109.8ms
# Speed: 1.4ms preprocess, 109.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 cars, 1 bus, 3 trucks, 109.3ms
# Speed: 1.4ms preprocess, 109.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cars, 1 bus, 3 trucks, 110.7ms
# Speed: 1.3ms preprocess, 110.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cars, 3 trucks, 109.2ms
# Speed: 1.3ms preprocess, 109.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cars, 3 trucks, 110.6ms
# Speed: 1.4ms preprocess, 110.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cars, 3 trucks, 111.4ms
# Speed: 1.5ms preprocess, 111.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 bus, 3 trucks, 110.0ms
# Speed: 1.5ms preprocess, 110.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 1 bus, 3 trucks, 113.2ms
# Speed: 1.3ms preprocess, 113.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 cars, 1 bus, 3 trucks, 107.2ms
# Speed: 1.4ms preprocess, 107.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cars, 1 bus, 2 trucks, 109.8ms
# Speed: 1.5ms preprocess, 109.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 3 trucks, 113.3ms
# Speed: 1.7ms preprocess, 113.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 3 trucks, 110.5ms
# Speed: 1.6ms preprocess, 110.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 3 trucks, 110.0ms
# Speed: 1.4ms preprocess, 110.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 3 trucks, 110.7ms
# Speed: 1.5ms preprocess, 110.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 3 trucks, 116.4ms
# Speed: 1.5ms preprocess, 116.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 4 trucks, 115.8ms
# Speed: 1.5ms preprocess, 115.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cars, 5 trucks, 110.1ms
# Speed: 1.5ms preprocess, 110.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cars, 5 trucks, 110.7ms
# Speed: 1.4ms preprocess, 110.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 5 trucks, 111.4ms
# Speed: 1.5ms preprocess, 111.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cars, 6 trucks, 111.5ms
# Speed: 1.4ms preprocess, 111.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 20 cars, 5 trucks, 113.9ms
# Speed: 1.6ms preprocess, 113.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cars, 5 trucks, 114.6ms
# Speed: 1.3ms preprocess, 114.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cars, 5 trucks, 111.9ms
# Speed: 1.4ms preprocess, 111.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 5 trucks, 108.3ms
# Speed: 1.4ms preprocess, 108.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 5 trucks, 111.2ms
# Speed: 1.5ms preprocess, 111.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cars, 5 trucks, 111.3ms
# Speed: 1.5ms preprocess, 111.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 5 trucks, 112.0ms
# Speed: 1.3ms preprocess, 112.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 4 trucks, 110.3ms
# Speed: 1.6ms preprocess, 110.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 4 trucks, 111.5ms
# Speed: 1.5ms preprocess, 111.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 5 trucks, 108.9ms
# Speed: 1.5ms preprocess, 108.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 4 trucks, 112.2ms
# Speed: 1.5ms preprocess, 112.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 4 trucks, 113.1ms
# Speed: 1.4ms preprocess, 113.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 3 trucks, 110.7ms
# Speed: 1.6ms preprocess, 110.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 2 trucks, 113.1ms
# Speed: 1.4ms preprocess, 113.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 4 trucks, 110.3ms
# Speed: 1.4ms preprocess, 110.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 4 trucks, 114.6ms
# Speed: 1.5ms preprocess, 114.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 3 trucks, 112.8ms
# Speed: 1.6ms preprocess, 112.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 4 trucks, 112.4ms
# Speed: 1.5ms preprocess, 112.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 4 trucks, 109.7ms
# Speed: 1.6ms preprocess, 109.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 23 cars, 5 trucks, 128.9ms
# Speed: 1.7ms preprocess, 128.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cars, 6 trucks, 112.5ms
# Speed: 1.4ms preprocess, 112.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cars, 6 trucks, 111.0ms
# Speed: 1.5ms preprocess, 111.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 24 cars, 4 trucks, 110.9ms
# Speed: 1.5ms preprocess, 110.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 6 trucks, 109.8ms
# Speed: 1.6ms preprocess, 109.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 4 trucks, 112.9ms
# Speed: 1.5ms preprocess, 112.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 1 bus, 6 trucks, 111.1ms
# Speed: 1.4ms preprocess, 111.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 6 trucks, 113.5ms
# Speed: 1.4ms preprocess, 113.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 6 trucks, 109.6ms
# Speed: 1.4ms preprocess, 109.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cars, 6 trucks, 115.0ms
# Speed: 1.4ms preprocess, 115.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 6 trucks, 110.4ms
# Speed: 1.4ms preprocess, 110.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cars, 6 trucks, 107.9ms
# Speed: 1.6ms preprocess, 107.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 24 cars, 6 trucks, 111.5ms
# Speed: 1.4ms preprocess, 111.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 6 trucks, 112.2ms
# Speed: 1.4ms preprocess, 112.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 23 cars, 6 trucks, 111.3ms
# Speed: 1.5ms preprocess, 111.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 22 cars, 6 trucks, 111.5ms
# Speed: 1.6ms preprocess, 111.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 6 trucks, 113.3ms
# Speed: 1.5ms preprocess, 113.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 5 trucks, 109.8ms
# Speed: 1.5ms preprocess, 109.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 5 trucks, 111.7ms
# Speed: 1.4ms preprocess, 111.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 5 trucks, 111.2ms
# Speed: 1.3ms preprocess, 111.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 6 trucks, 104.9ms
# Speed: 1.5ms preprocess, 104.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 22 cars, 5 trucks, 106.1ms
# Speed: 1.6ms preprocess, 106.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 4 trucks, 105.3ms
# Speed: 1.5ms preprocess, 105.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cars, 4 trucks, 108.5ms
# Speed: 1.4ms preprocess, 108.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 26 cars, 5 trucks, 111.2ms
# Speed: 1.6ms preprocess, 111.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cars, 5 trucks, 113.6ms
# Speed: 1.6ms preprocess, 113.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cars, 5 trucks, 109.5ms
# Speed: 1.5ms preprocess, 109.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 26 cars, 5 trucks, 113.3ms
# Speed: 1.5ms preprocess, 113.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 22 cars, 5 trucks, 118.0ms
# Speed: 1.7ms preprocess, 118.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 4 trucks, 114.9ms
# Speed: 1.5ms preprocess, 114.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 5 trucks, 114.7ms
# Speed: 1.4ms preprocess, 114.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 5 trucks, 110.4ms
# Speed: 1.4ms preprocess, 110.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 4 trucks, 114.8ms
# Speed: 1.4ms preprocess, 114.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 4 trucks, 111.7ms
# Speed: 1.6ms preprocess, 111.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 4 trucks, 110.3ms
# Speed: 1.5ms preprocess, 110.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 4 trucks, 114.5ms
# Speed: 1.4ms preprocess, 114.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 23 cars, 6 trucks, 119.8ms
# Speed: 1.6ms preprocess, 119.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 21 cars, 6 trucks, 113.6ms
# Speed: 1.5ms preprocess, 113.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# ...
#
# 0: 384x640 1 person, 14 cars, 5 trucks, 93.3ms
# Speed: 1.4ms preprocess, 93.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 7 trucks, 100.2ms
# Speed: 1.4ms preprocess, 100.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 14 cars, 7 trucks, 102.4ms
# Speed: 1.5ms preprocess, 102.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 14 cars, 6 trucks, 163.4ms
# Speed: 1.5ms preprocess, 163.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 7 trucks, 100.8ms
# Speed: 1.7ms preprocess, 100.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 7 trucks, 99.6ms
# Speed: 1.5ms preprocess, 99.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 7 trucks, 100.0ms
# Speed: 1.5ms preprocess, 100.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 7 trucks, 102.9ms
# Speed: 1.4ms preprocess, 102.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 6 trucks, 104.1ms
# Speed: 1.5ms preprocess, 104.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 6 trucks, 101.6ms
# Speed: 1.3ms preprocess, 101.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 6 trucks, 100.7ms
# Speed: 1.4ms preprocess, 100.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 7 trucks, 101.8ms
# Speed: 1.6ms preprocess, 101.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 7 trucks, 104.8ms
# Speed: 1.5ms preprocess, 104.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 7 trucks, 103.7ms
# Speed: 1.5ms preprocess, 103.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 6 trucks, 100.8ms
# Speed: 1.6ms preprocess, 100.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 6 trucks, 100.6ms
# Speed: 1.5ms preprocess, 100.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 1 bus, 6 trucks, 101.2ms
# Speed: 1.4ms preprocess, 101.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 8 trucks, 103.6ms
# Speed: 1.3ms preprocess, 103.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 8 trucks, 108.5ms
# Speed: 1.5ms preprocess, 108.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 1 bus, 8 trucks, 105.1ms
# Speed: 1.6ms preprocess, 105.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 1 bus, 9 trucks, 106.7ms
# Speed: 1.6ms preprocess, 106.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 13 cars, 1 bus, 9 trucks, 108.4ms
# Speed: 1.5ms preprocess, 108.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 8 trucks, 98.3ms
# Speed: 1.4ms preprocess, 98.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 8 trucks, 98.4ms
# Speed: 1.4ms preprocess, 98.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 8 trucks, 101.6ms
# Speed: 1.6ms preprocess, 101.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 14 cars, 8 trucks, 101.5ms
# Speed: 1.5ms preprocess, 101.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 7 trucks, 97.9ms
# Speed: 1.4ms preprocess, 97.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 14 cars, 7 trucks, 98.5ms
# Speed: 1.4ms preprocess, 98.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 13 cars, 8 trucks, 98.0ms
# Speed: 1.5ms preprocess, 98.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 14 cars, 8 trucks, 100.6ms
# Speed: 1.4ms preprocess, 100.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 14 cars, 8 trucks, 99.6ms
# Speed: 1.4ms preprocess, 99.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 13 cars, 8 trucks, 111.5ms
# Speed: 1.5ms preprocess, 111.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 17 cars, 7 trucks, 100.1ms
# Speed: 1.4ms preprocess, 100.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 15 cars, 7 trucks, 101.2ms
# Speed: 1.4ms preprocess, 101.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 15 cars, 8 trucks, 99.8ms
# Speed: 1.5ms preprocess, 99.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 14 cars, 7 trucks, 99.5ms
# Speed: 1.5ms preprocess, 99.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 14 cars, 7 trucks, 100.1ms
# Speed: 1.4ms preprocess, 100.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 15 cars, 7 trucks, 99.6ms
# Speed: 1.5ms preprocess, 99.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 15 cars, 7 trucks, 106.3ms
# Speed: 1.5ms preprocess, 106.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 14 cars, 8 trucks, 100.6ms
# Speed: 1.4ms preprocess, 100.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 14 cars, 8 trucks, 102.4ms
# Speed: 1.6ms preprocess, 102.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 14 cars, 8 trucks, 98.7ms
# Speed: 1.4ms preprocess, 98.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 14 cars, 8 trucks, 99.6ms
# Speed: 1.4ms preprocess, 99.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 14 cars, 8 trucks, 99.9ms
# Speed: 1.4ms preprocess, 99.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 14 cars, 8 trucks, 106.4ms
# Speed: 1.5ms preprocess, 106.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 14 cars, 8 trucks, 100.4ms
# Speed: 1.4ms preprocess, 100.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 12 cars, 8 trucks, 99.2ms
# Speed: 1.6ms preprocess, 99.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 14 cars, 7 trucks, 99.5ms
# Speed: 1.5ms preprocess, 99.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 14 cars, 7 trucks, 100.0ms
# Speed: 1.5ms preprocess, 100.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 7 trucks, 99.3ms
# Speed: 1.4ms preprocess, 99.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 15 cars, 6 trucks, 97.2ms
# Speed: 1.5ms preprocess, 97.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 14 cars, 7 trucks, 98.9ms
# Speed: 1.5ms preprocess, 98.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 1 license_plate, 44.7ms
# Speed: 1.7ms preprocess, 44.7ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 person, 13 cars, 6 trucks, 104.2ms
# Speed: 1.6ms preprocess, 104.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [([[15, 11], [181, 11], [181, 53], [15, 53]], '6Jo6 EPD', 0.6862278200025252)]
# 0: 544x640 1 license_plate, 45.1ms
# Speed: 1.7ms preprocess, 45.1ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 2 persons, 14 cars, 6 trucks, 107.6ms
# Speed: 1.5ms preprocess, 107.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [([[17, 11], [181, 11], [181, 53], [17, 53]], '6Jo6 EPD:', 0.6628534391365035)]
# 0: 544x640 1 license_plate, 45.0ms
# Speed: 1.8ms preprocess, 45.0ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
# [([[15, 11], [181, 11], [181, 53], [15, 53]], '6Jo6 EPD', 0.41450770913873014)]
# 0: 384x640 2 persons, 14 cars, 6 trucks, 112.5ms
# Speed: 2.2ms preprocess, 112.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 1 license_plate, 47.2ms
# Speed: 1.6ms preprocess, 47.2ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 person, 15 cars, 7 trucks, 107.8ms
# Speed: 2.3ms preprocess, 107.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [([[18, 8], [185, 8], [185, 53], [18, 53]], '6Jo6 EPD', 0.5207044817816435)]
# 0: 544x640 1 license_plate, 46.8ms
# Speed: 1.8ms preprocess, 46.8ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 2 persons, 13 cars, 6 trucks, 109.0ms
# Speed: 1.8ms preprocess, 109.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [([[19, 11], [185, 11], [185, 55], [19, 55]], '6Jo6 EPD', 0.8688004095886447)]
# 0: 544x640 1 license_plate, 47.5ms
# Speed: 1.9ms preprocess, 47.5ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 2 persons, 14 cars, 6 trucks, 110.0ms
# Speed: 1.7ms preprocess, 110.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [([[14, 10], [181, 10], [181, 55], [14, 55]], '6JO6 EPD', 0.7143699218070946)]
# 0: 544x640 1 license_plate, 47.0ms
# Speed: 1.7ms preprocess, 47.0ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 2 persons, 15 cars, 7 trucks, 111.4ms
# Speed: 2.1ms preprocess, 111.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [([[15, 13], [183, 13], [183, 57], [15, 57]], '6Jo6 EPD', 0.7419437532780028)]
# 0: 544x640 1 license_plate, 46.2ms
# Speed: 1.7ms preprocess, 46.2ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 2 persons, 15 cars, 6 trucks, 106.8ms
# Speed: 2.1ms preprocess, 106.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# [([[14, 10], [181, 10], [181, 53], [14, 53]], '6Jo6 EPD', 0.44577714212722197)]
# 0: 544x640 1 license_plate, 46.2ms
# Speed: 2.0ms preprocess, 46.2ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 2 persons, 15 cars, 6 trucks, 111.6ms
# Speed: 1.6ms preprocess, 111.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [([[17, 9], [185, 9], [185, 53], [17, 53]], '6JO6 EPD', 0.614046182484212)]
# 0: 544x640 1 license_plate, 45.8ms
# Speed: 1.7ms preprocess, 45.8ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 2 persons, 15 cars, 6 trucks, 104.4ms
# Speed: 1.5ms preprocess, 104.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [([[17, 9], [185, 9], [185, 53], [17, 53]], '6JO6 EPD', 0.614046182484212)]
# 0: 544x640 1 license_plate, 44.3ms
# Speed: 1.8ms preprocess, 44.3ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 person, 14 cars, 6 trucks, 106.3ms
# Speed: 2.0ms preprocess, 106.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [([[0, 11], [177, 11], [177, 53], [0, 53]], 'LJos EPD', 0.56294509243302)]
# 0: 544x640 1 license_plate, 45.2ms
# Speed: 1.6ms preprocess, 45.2ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 2 persons, 14 cars, 6 trucks, 106.3ms
# Speed: 2.1ms preprocess, 106.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [([[1, 11], [171, 11], [171, 53], [1, 53]], 'GJos EPD', 0.6273159049045142)]
# 0: 544x640 1 license_plate, 45.9ms
# Speed: 1.9ms preprocess, 45.9ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
# [([[9, 11], [177, 11], [177, 53], [9, 53]], '6Jo6 EPD', 0.5905029782876263)]
# 0: 384x640 2 persons, 14 cars, 5 trucks, 116.0ms
# Speed: 1.9ms preprocess, 116.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 1 license_plate, 46.8ms
# Speed: 1.8ms preprocess, 46.8ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 2 persons, 14 cars, 6 trucks, 109.6ms
# Speed: 1.7ms preprocess, 109.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [([[9, 11], [179, 11], [179, 53], [9, 53]], '6Jo6 EPD', 0.5245312865626638)]
# 0: 544x640 1 license_plate, 45.8ms
# Speed: 1.7ms preprocess, 45.8ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
# [([[9, 11], [177, 11], [177, 53], [9, 53]], '6Jo6 Epd', 0.4594760904803391)]
# 0: 384x640 2 persons, 14 cars, 6 trucks, 109.9ms
# Speed: 2.2ms preprocess, 109.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 1 license_plate, 46.8ms
# Speed: 1.8ms preprocess, 46.8ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 2 persons, 14 cars, 6 trucks, 106.5ms
# Speed: 2.4ms preprocess, 106.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [([[10, 6], [179, 6], [179, 51], [10, 51]], '6Jo6 EPd)', 0.13377110499340913)]
# 0: 544x640 1 license_plate, 46.9ms
# Speed: 1.8ms preprocess, 46.9ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 person, 14 cars, 6 trucks, 105.9ms
# Speed: 1.5ms preprocess, 105.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [([[37, 11], [179, 11], [179, 53], [37, 53]], 'Jo6 EPd', 0.5443863613344007)]
# 0: 544x640 1 license_plate, 47.4ms
# Speed: 1.7ms preprocess, 47.4ms inference, 1.8ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 2 persons, 14 cars, 6 trucks, 108.7ms
# Speed: 1.6ms preprocess, 108.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [([[11, 7], [182, 7], [182, 56], [11, 56]], '6JOG EPD', 0.465034551231642)]
# 0: 544x640 1 license_plate, 46.5ms
# Speed: 1.9ms preprocess, 46.5ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
# [([[8, 10], [179, 10], [179, 54], [8, 54]], 'gJo6 EPD', 0.21708031317010718)]
# 0: 384x640 1 person, 14 cars, 6 trucks, 116.3ms
# Speed: 2.6ms preprocess, 116.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 1 license_plate, 46.1ms
# Speed: 1.8ms preprocess, 46.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
# [([[13, 11], [181, 11], [181, 55], [13, 55]], '6Jo6 Epd', 0.624743524093439)]
# 0: 384x640 1 person, 14 cars, 7 trucks, 112.6ms
# Speed: 2.4ms preprocess, 112.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 1 license_plate, 49.1ms
# Speed: 1.8ms preprocess, 49.1ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 person, 14 cars, 7 trucks, 105.0ms
# Speed: 1.6ms preprocess, 105.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [([[9, 11], [179, 11], [179, 55], [9, 55]], 'GJo6 EPD', 0.3849233275847759)]
# 0: 544x640 1 license_plate, 46.2ms
# Speed: 1.9ms preprocess, 46.2ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 15 cars, 7 trucks, 106.6ms
# Speed: 1.5ms preprocess, 106.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [([[0, 13], [181, 13], [181, 57], [0, 57]], '6Jo6 Epd', 0.6109004249256563)]
# 0: 544x640 1 license_plate, 47.1ms
# Speed: 1.7ms preprocess, 47.1ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 person, 15 cars, 7 trucks, 105.9ms
# Speed: 1.8ms preprocess, 105.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [([[9, 13], [181, 13], [181, 55], [9, 55]], 'GJO6 EPD', 0.4266864282866335)]
# 0: 544x640 1 license_plate, 49.3ms
# Speed: 1.8ms preprocess, 49.3ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
